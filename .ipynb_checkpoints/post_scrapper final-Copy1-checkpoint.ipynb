# %% [markdown]
# # CISCO Post Scraper And Preliminary Analysation
#
# #### LOADING DEPENDENCIES

# %%
import requests
import bs4

# %% [markdown]
# ##### class post_info
#
#
# Creating post_info class which bundles all relevant info to a post

# %%
class post_info:
    def __init__(self,post,date,views,upvotes,replies,link,resolved):
        self.post = post
        self.date = date
        self.upvotes = int(upvotes)
        self.replies = int(replies)
        self.views = int(views)
        self.link = link
        self.resolved = resolved
        
    def disp_info(self):
        print("\n\nPost : " +self.post+"\nDate : "+self.date+ "\nReplies : "+str(self.replies) +"\t\t views : "+str(self.views)+"\t\t upvotes :"+str(self.upvotes )+"\t\t resolved : "+str(self.resolved)+"\nLink : "+self.link)

# %% [markdown]
# #### SCRAPING HELPER FUNCTIONS
#
# ##### load_page(url)
#
# Thisfunction loads all the post in the page of given "url" and returns a list of post_info class object
#
# parameter(s) :
#     url : page link

# %%
def load_page(url):
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    
    posts = []
    
    raw_replies = (soup.select("div.lia-quilt-column-alley-left tr.lia-list-row div.lia-component-messages-column-thread-replies-count span"))
    n_rep = len(raw_replies)
    
    replies = []
    for reply in raw_replies:
        replies.append(reply.getText())
        
        
    raw_views = soup.select("div.lia-quilt-column-alley-left tr.lia-list-row div.lia-component-messages-column-topic-views-count span")
    n_views = len(raw_views)
    
    views = []
    for view in raw_views:
        views.append(view.getText())
        
        
    raw_dates = (soup.select("div.lia-quilt-column-alley-left tr.lia-list-row div.lia-info-area > span:nth-of-type(1) span.local-date"))
    n_dates = len(raw_dates)
    
    dates = []
    for date in raw_dates:
        dates.append(date.getText()[1:])
        
    
    raw_titles = (soup.select("div.lia-quilt-column-alley-left tr.lia-list-row div.MessageSubject a.lia-custom-event.lia-link-navigation.page-link"))
    n_titles = len(raw_titles)
    
    titles = []
    for title in raw_titles:
        _t = title.getText().split()
        titles.append(" ".join(_t))
    
    
    raw_upvotes = soup.select("div.lia-quilt-column-alley-left tr.lia-list-row div.custom-grid-kudos span")
    n_upvotes = len(raw_upvotes)
    
    upvotes = []
    for upvote in raw_upvotes:
        upvotes.append(upvote.getText()[4:-3])
        
    links_html = soup.select('div.lia-quilt-column-alley-left tr.lia-list-row a.page-link.lia-link-navigation.lia-custom-event')
    n_links = len(links_html)
    
    links = []
    for link in links_html:
        links.append('https://supportforums.cisco.com/'+link.attrs["href"])
    
    trs = soup.select('div.lia-quilt-column-alley-left tbody tr')
    n_res = len(trs)
    
    resolved = []
    for tr in trs:
        resolved.append(len(tr.find_all("td",{"aria-label" : "This thread is solved"})))
    
    
        
    if n_rep == n_upvotes == n_titles == n_dates == n_views == n_res:
        
        print("number of posts : "+str(n_rep))
        
        for i in range(n_titles):
            posts.append(post_info(titles[i],dates[i],views[i],upvotes[i],replies[i],links[i],resolved[i]))
        
        return posts
    
    else:
        
        print("error encountered : unequal data contraints")
        
        print("number of replies : "+str(n_rep))
        print("number of views " + str(n_views))
        print("number of upvotes " +str(n_upvotes))
        print("number of dates " +str(n_dates))
        print("number of titles "+str(n_titles))
        
        return None

# %% [markdown]
# ##### load_topic(base_url, num_pages, start_page = 50,sep_pages = False, display = False)
#
#
# This function loads pages from a particular topics base url
#
#
# parameters :
#
#
#     base_url : base url of given topic
#
#     num_pages : number of pages to be loaded
#
#     start_page : starting page number for scraping
#
#     sep_pages : if True returns list of list of page posts
#
#     display : Set true to display results after completion

# %%
def load_topic(base_url, num_pages, start_page = 50,sep_pages = False, display = False):
    
    all_posts = []
    sep_posts = []
    
    for i in range(num_pages):
        
        load_url = base_url + str(start_page+i)
        page_posts = load_page(load_url)
        
        sep_posts.append(page_posts)
        all_posts.extend(page_posts)
        
        if page_posts != None:
            print("page number : "+str(start_page+i) + " loaded successfully")
        else:
            print("page number : "+str(start_page+i) + " load error")
            return all_posts
        
    if display:
        for i in range(len(all_posts)):
            all_posts[i].disp_info()
            
    if sep_pages :
        return sep_posts
    else:
        return all_posts

# %%
base_url = 'https://supportforums.cisco.com/t5/lan-switching-and-routing/bd-p/6016-discussions-lan-switching-routing/page/'
posts = load_topic(base_url, num_pages = 100, start_page = 650,sep_pages = False, display = False )
# Out:
# number of posts : 15
# page number : 650 loaded successfully
# number of posts : 15
# page number : 651 loaded successfully
# number of posts : 15
# page number : 652 loaded successfully
# number of posts : 15
# page number : 653 loaded successfully
# number of posts : 15
# page number : 654 loaded successfully
# number of posts : 15
# page number : 655 loaded successfully
# number of posts : 15
# page number : 656 loaded successfully
# number of posts : 15
# page number : 657 loaded successfully
# number of posts : 15
# page number : 658 loaded successfully
# number of posts : 15
# page number : 659 loaded successfully
# number of posts : 15
# page number : 660 loaded successfully
# number of posts : 15
# page number : 661 loaded successfully
# number of posts : 15
# page number : 662 loaded successfully
# number of posts : 15
# page number : 663 loaded successfully
# number of posts : 15
# page number : 664 loaded successfully
# number of posts : 15
# page number : 665 loaded successfully
# number of posts : 15
# page number : 666 loaded successfully
# number of posts : 15
# page number : 667 loaded successfully
# number of posts : 15
# page number : 668 loaded successfully
# number of posts : 15
# page number : 669 loaded successfully
# number of posts : 15
# page number : 670 loaded successfully
# number of posts : 15
# page number : 671 loaded successfully
# number of posts : 15
# page number : 672 loaded successfully
# number of posts : 15
# page number : 673 loaded successfully
# number of posts : 15
# page number : 674 loaded successfully
# number of posts : 15
# page number : 675 loaded successfully
# number of posts : 15
# page number : 676 loaded successfully
# number of posts : 15
# page number : 677 loaded successfully
# number of posts : 15
# page number : 678 loaded successfully
# number of posts : 15
# page number : 679 loaded successfully
# number of posts : 15
# page number : 680 loaded successfully
# number of posts : 15
# page number : 681 loaded successfully
# number of posts : 15
# page number : 682 loaded successfully
# number of posts : 15
# page number : 683 loaded successfully
# number of posts : 15
# page number : 684 loaded successfully
# number of posts : 15
# page number : 685 loaded successfully
# number of posts : 15
# page number : 686 loaded successfully
# number of posts : 15
# page number : 687 loaded successfully
# number of posts : 15
# page number : 688 loaded successfully
# number of posts : 15
# page number : 689 loaded successfully
# number of posts : 15
# page number : 690 loaded successfully
# number of posts : 15
# page number : 691 loaded successfully
# number of posts : 15
# page number : 692 loaded successfully
# number of posts : 15
# page number : 693 loaded successfully
# number of posts : 15
# page number : 694 loaded successfully
# number of posts : 15
# page number : 695 loaded successfully
# number of posts : 15
# page number : 696 loaded successfully
# number of posts : 15
# page number : 697 loaded successfully
# number of posts : 15
# page number : 698 loaded successfully
# number of posts : 15
# page number : 699 loaded successfully
# number of posts : 15
# page number : 700 loaded successfully
# number of posts : 15
# page number : 701 loaded successfully
# number of posts : 15
# page number : 702 loaded successfully
# number of posts : 15
# page number : 703 loaded successfully
# number of posts : 15
# page number : 704 loaded successfully
# number of posts : 15
# page number : 705 loaded successfully
# number of posts : 15
# page number : 706 loaded successfully
# number of posts : 15
# page number : 707 loaded successfully
# number of posts : 15
# page number : 708 loaded successfully
# number of posts : 15
# page number : 709 loaded successfully
# number of posts : 15
# page number : 710 loaded successfully
# number of posts : 15
# page number : 711 loaded successfully
# number of posts : 15
# page number : 712 loaded successfully
# number of posts : 15
# page number : 713 loaded successfully
# number of posts : 15
# page number : 714 loaded successfully
# number of posts : 15
# page number : 715 loaded successfully
# number of posts : 15
# page number : 716 loaded successfully
# number of posts : 15
# page number : 717 loaded successfully
# number of posts : 15
# page number : 718 loaded successfully
# number of posts : 15
# page number : 719 loaded successfully
# number of posts : 15
# page number : 720 loaded successfully
# number of posts : 15
# page number : 721 loaded successfully
# number of posts : 15
# page number : 722 loaded successfully
# number of posts : 15
# page number : 723 loaded successfully
# number of posts : 15
# page number : 724 loaded successfully
# number of posts : 15
# page number : 725 loaded successfully
# number of posts : 15
# page number : 726 loaded successfully
# number of posts : 15
# page number : 727 loaded successfully
# number of posts : 15
# page number : 728 loaded successfully
# number of posts : 15
# page number : 729 loaded successfully
# number of posts : 15
# page number : 730 loaded successfully
# number of posts : 15
# page number : 731 loaded successfully
# number of posts : 15
# page number : 732 loaded successfully
# number of posts : 15
# page number : 733 loaded successfully
# number of posts : 15
# page number : 734 loaded successfully
# number of posts : 15
# page number : 735 loaded successfully
# number of posts : 15
# page number : 736 loaded successfully
# number of posts : 15
# page number : 737 loaded successfully
# number of posts : 15
# page number : 738 loaded successfully
# number of posts : 15
# page number : 739 loaded successfully
# number of posts : 15
# page number : 740 loaded successfully
# number of posts : 15
# page number : 741 loaded successfully
# number of posts : 15
# page number : 742 loaded successfully
# number of posts : 15
# page number : 743 loaded successfully
# number of posts : 15
# page number : 744 loaded successfully
# number of posts : 15
# page number : 745 loaded successfully
# number of posts : 15
# page number : 746 loaded successfully
# number of posts : 15
# page number : 747 loaded successfully
# number of posts : 15
# page number : 748 loaded successfully
# number of posts : 15
# page number : 749 loaded successfully

# %%
print(len(posts))
# Out:
# 1500

# %%
posts[0].disp_info()
# Out:
# Post : Carry two vlans on a switchport
# Date : 02-21-2017
# Replies : 5		 views : 101		 upvotes :0		 resolved : 1
# Link : https://supportforums.cisco.com//t5/lan-switching-and-routing/carry-two-vlans-on-a-switchport/td-p/3035905

# %%
import string
def save_csv(posts,filename):
    
    csv = open(filename, "w",encoding='utf-8')
    columnTitleRow = "Post,Date,Views,Replies,Upvotes,Link,Resolved\n"
    csv.write(columnTitleRow)
    table = str.maketrans({key: None for key in string.punctuation})
    
    for post in posts:
        post_string = post.post.translate(table) 
        row = post_string + "," + post.date + "," + str(post.views) + "," + str(post.replies) + "," + str(post.upvotes) + "," +post.link+"," + str(post.resolved)+ "\n"
        csv.write(row)

# %%
save_csv(posts,"posts2.csv")

# %%
import pandas as pd
data = pd.read_csv("LAN_Switching_Routing_info.csv",parse_dates=['Date'])

print(len(data))
data.head(15)
# Out:
# 10500
#                                       Post       Date  Views  Replies  \
# 0    IOS Upgrade on cisco WSC6509E switche 2018-05-23     83        1
# 1    C68008P10G Interface Module Installat 2018-05-23    141        6
# 2              Cisco ACI mode vs NXOS Mode 2018-05-22    217        3
# 3               Visio stencil CISCO 892FSP 2016-11-14    586        4
# 4              Problem with a simple route 2018-05-22    129        5
# 5    Authorization failed on Routers for a 2018-05-22    119        9
# 6    cisco catalyst 3850 license downgrade 2018-05-22    146        1
# 7      SNMP community with nonexisting ACL 2018-05-22    139        2
# 8                Dropping 6th ICMP packets 2011-04-25  10455        9
# 9     problem enable ssh switch C4500X16FP 2018-05-22    109        5
# 10                    Facebook login blcok 2018-05-18    204       10
# 11         ASR 9000 Link Bundling for 100G 2018-05-22    101        0
# 12                Portchannel and dual ISP 2018-05-22     65        1
# 13   ISR 4431 Console Output During Reload 2018-05-12    146        5
# 14                           NAT with VRF  2014-12-22   3184       11
#
#     Upvotes                                               Link  Resolved
# 0         0  https://supportforums.cisco.com//t5/lan-switch...         0
# 1         0  https://supportforums.cisco.com//t5/lan-switch...         1
# 2         0  https://supportforums.cisco.com//t5/lan-switch...         1
# 3         0  https://supportforums.cisco.com//t5/lan-switch...         0
# 4        10  https://supportforums.cisco.com//t5/lan-switch...         0
# 5         0  https://supportforums.cisco.com//t5/lan-switch...         0
# 6         0  https://supportforums.cisco.com//t5/lan-switch...         1
# 7         0  https://supportforums.cisco.com//t5/lan-switch...         1
# 8        10  https://supportforums.cisco.com//t5/lan-switch...         1
# 9         5  https://supportforums.cisco.com//t5/lan-switch...         0
# 10        0  https://supportforums.cisco.com//t5/lan-switch...         0
# 11        0  https://supportforums.cisco.com//t5/lan-switch...         0
# 12        0  https://supportforums.cisco.com//t5/lan-switch...         0
# 13        0  https://supportforums.cisco.com//t5/lan-switch...         0
# 14        0  https://supportforums.cisco.com//t5/lan-switch...         0

# %% [markdown]
# ### Loaded Topics
#
# The following Topic datasets will be used for analysis which contain all the posts info for the period jan 2017 and april 2018 .

# %% [markdown]
# | index | Topic Name                   | filename                       | Size  |
# |-------|------------------------------|--------------------------------|-------|
# |   1.  |   WAN, Routing and Switching | WAN_Routing_Switching_info.csv | 4800  |
# |   2.  |   LAN, Switching and Routing | LAN_Switching_Routing_info.csv | 10500 |
# |   3.  |   IP Telephony               | IP_telephony_info.csv          | 6750  |
# |   4.  |   Firewalling                | Firewalling_info.csv           | 3750  |

# %% [markdown]
# ## RETRIEVING POST DATA
#
#
# A post_data class object stores post attributes such as heading , content and replies bundled together.

# %%
class post_data:
    def __init__(self,heading,content,replies):
        self.heading = heading
        self.content = content
        self.replies = replies
        
    def disp_info(self):
        print("HEADING :\t"+self.heading)
        print("\n\nPOST :\n\n"+self.content)
        print("\nREPLIES :\t")
        if len(self.replies):
            for reply in self.replies:
                print("\n\n"+reply)
        else:
            print("No Replies!")

# %% [markdown]
# ##### scrape_post_data(load_url,display = False)
#
# this function extract post info by going to post page.
#
# parameters:
#
#     load_url: link to post discussion page.
#
#     display: set to True to display posts while scraping.

# %%
def scrape_post_data(load_url,display = False):
    res = requests.get(load_url,timeout = 6)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    
    heading = soup.select("div.lia-thread-topic h5")[0].getText()
    
    paras = soup.select("div.lia-thread-topic p")
    content = ""
    for para in paras:
        content += (para.getText())
    content = content.split()
    content = " ".join(content)
    
    replies_html = soup.select("div.lia-thread-reply div.lia-message-body")
    replies = []
    for reply in replies_html:
        reply = reply.getText().split()
        reply = " ".join(reply)
        replies.append(reply)
        
    post = post_data(heading,content,replies) 
        
    if display:
        post.disp_info()
            
    return post

# %% [markdown]
# ##### post_data_loader(data,num_pages=3,start_page=0)
#
# This function loads post data by calling scrape_post_data() function .
#
# paramenters:
#
#     data: pandas dataframe containing info about post references .
#
#     num_pages : number of pages whose post data you want to scrape.
#
#     start_page : the page you want the scraping to start with.
#
#     NOTE: each page contains 15 posts so while choosing number of pages be careful about the number of links that you scrape
#     because if it is too big then it may cause timeouterror.

# %%
def post_data_loader(data,num_pages=3,start_page=0):
    if((num_pages+start_page)*15 <= len(data)):
        links = data['Link'].tolist()[start_page*15:(num_pages+start_page)*15]
        post_dat = []
        for i,link in enumerate(links):
            post_dat.append(scrape_post_data(link))
            #if(i%5 == 0):
            print("Post : "+str(i)+" loaded")
        return post_dat
    else:
        print("Invalid Inputs")

# %%
import pandas as pd
data = pd.read_csv("Firewalling_info.csv",parse_dates=['Date'])

print(len(data))
data.head(15)
# Out:
# 3750
#                                        Post       Date  Views  Replies  \
# 0          ASA 5508X FTDASDMFMC Limitations 2018-05-16    181        1
# 1    Convert Asav Ova files to qcow2 and in 2018-05-15     92        2
# 2    Cisco ASA DHCPPD and SLAAC with VPN An 2018-05-15    155        0
# 3              Cisco ASA use Sophos UTM IPS 2018-05-14    185        4
# 4   Cisco ASA 5512 Blocking PPTP connection 2018-05-11    193       10
# 5                  ASA High CPU Utilization 2018-05-14    146       13
# 6    Cisco Firepower 2110 Threat Defense  A 2018-05-15    120        0
# 7    ASA with Websense  selective request f 2018-05-11     93        1
# 8            Create packet on packet tracer 2018-05-15    123        0
# 9   Need help understand ASA with firepower 2018-05-13    253       11
# 10                Blocking Plum Voice login 2018-05-14     77        1
# 11   Cisco ASA 5510 Error 15 file not found 2013-03-07  10763       18
# 12  Question about Firepower license migrat 2018-05-14    212        3
# 13            ASA 5525 failover key failure 2018-05-07    344       15
# 14     Firepower chassis add data interface 2018-05-14     67        3
#
#     Upvotes                                               Link  Resolved
# 0         5  https://supportforums.cisco.com//t5/firewallin...         1
# 1         0  https://supportforums.cisco.com//t5/firewallin...         0
# 2         0  https://supportforums.cisco.com//t5/firewallin...         0
# 3         0  https://supportforums.cisco.com//t5/firewallin...         0
# 4         0  https://supportforums.cisco.com//t5/firewallin...         0
# 5         0  https://supportforums.cisco.com//t5/firewallin...         0
# 6         0  https://supportforums.cisco.com//t5/firewallin...         0
# 7         0  https://supportforums.cisco.com//t5/firewallin...         0
# 8         0  https://supportforums.cisco.com//t5/firewallin...         0
# 9        40  https://supportforums.cisco.com//t5/firewallin...         0
# 10        0  https://supportforums.cisco.com//t5/firewallin...         0
# 11        0  https://supportforums.cisco.com//t5/firewallin...         0
# 12        0  https://supportforums.cisco.com//t5/firewallin...         1
# 13       10  https://supportforums.cisco.com//t5/firewallin...         0
# 14        0  https://supportforums.cisco.com//t5/firewallin...         0

# %%
post_dat = post_data_loader(data,10,154)
# Out:
# Post : 0 loaded
# Post : 1 loaded
# Post : 2 loaded
# Post : 3 loaded
# Post : 4 loaded
# Post : 5 loaded
# Post : 6 loaded
# Post : 7 loaded
# Post : 8 loaded
# Post : 9 loaded
# Post : 10 loaded
# Post : 11 loaded
# Post : 12 loaded
# Post : 13 loaded
# Post : 14 loaded
# Post : 15 loaded
# Post : 16 loaded
# Post : 17 loaded
# Post : 18 loaded
# Post : 19 loaded
# Post : 20 loaded
# Post : 21 loaded
# Post : 22 loaded
# Post : 23 loaded
# Post : 24 loaded
# Post : 25 loaded
# Post : 26 loaded
# Post : 27 loaded
# Post : 28 loaded
# Post : 29 loaded
# Post : 30 loaded
# Post : 31 loaded
# Post : 32 loaded
# Post : 33 loaded
# Post : 34 loaded
# Post : 35 loaded
# Post : 36 loaded
# Post : 37 loaded
# Post : 38 loaded
# Post : 39 loaded
# Post : 40 loaded
# Post : 41 loaded
# Post : 42 loaded
# Post : 43 loaded
# Post : 44 loaded
# Post : 45 loaded
# Post : 46 loaded
# Post : 47 loaded
# Post : 48 loaded
# Post : 49 loaded
# Post : 50 loaded
# Post : 51 loaded
# Post : 52 loaded
# Post : 53 loaded
# Post : 54 loaded
# Post : 55 loaded
# Post : 56 loaded
# Post : 57 loaded
# Post : 58 loaded
# Post : 59 loaded
# Post : 60 loaded
# Post : 61 loaded
# Post : 62 loaded
# Post : 63 loaded
# Post : 64 loaded
# Post : 65 loaded
# Post : 66 loaded
# Post : 67 loaded
# Post : 68 loaded
# Post : 69 loaded
# Post : 70 loaded
# Post : 71 loaded
# Post : 72 loaded
# Post : 73 loaded
# Post : 74 loaded
# Post : 75 loaded
# Post : 76 loaded
# Post : 77 loaded
# Post : 78 loaded
# Post : 79 loaded
# Post : 80 loaded
# Post : 81 loaded
# Post : 82 loaded
# Post : 83 loaded
# Post : 84 loaded
# Post : 85 loaded
# Post : 86 loaded
# Post : 87 loaded
# Post : 88 loaded
# Post : 89 loaded
# Post : 90 loaded
# Post : 91 loaded
# Post : 92 loaded
# Post : 93 loaded
# Post : 94 loaded
# Post : 95 loaded
# Post : 96 loaded
# Post : 97 loaded
# Post : 98 loaded
# Post : 99 loaded
# Post : 100 loaded
# Post : 101 loaded
# Post : 102 loaded
# Post : 103 loaded
# Post : 104 loaded
# Post : 105 loaded
# Post : 106 loaded
# Post : 107 loaded
# Post : 108 loaded
# Post : 109 loaded
# Post : 110 loaded
# Post : 111 loaded
# Post : 112 loaded
# Post : 113 loaded
# Post : 114 loaded
# Post : 115 loaded
# Post : 116 loaded
# Post : 117 loaded
# Post : 118 loaded
# Post : 119 loaded
# Post : 120 loaded
# Post : 121 loaded
# Post : 122 loaded
# Post : 123 loaded
# Post : 124 loaded
# Post : 125 loaded
# Post : 126 loaded
# Post : 127 loaded
# Post : 128 loaded
# Post : 129 loaded
# Post : 130 loaded
# Post : 131 loaded
# Post : 132 loaded
# Post : 133 loaded
# Post : 134 loaded
# Post : 135 loaded
# Post : 136 loaded
# Post : 137 loaded
# Post : 138 loaded
# Post : 139 loaded
# Post : 140 loaded
# Post : 141 loaded
# Post : 142 loaded
# Post : 143 loaded
# Post : 144 loaded
# Post : 145 loaded
# Post : 146 loaded
# Post : 147 loaded
# Post : 148 loaded
# Post : 149 loaded

# %%
post_dat[0].disp_info()
# Out:
# HEADING :	what is the best way to configure ASA5515 logs , when we dont have external logging server
#
#
# POST :
#
# what is the best way to configure ASA5515 logs , when we dont have external logging server
#
# REPLIES :
#
#
# You should really use an external syslog server. Even the free version of Solarwinds' Kiwi syslog server is useful. Since the local log buffer will quickly fill up for the more verbose log messages like Notification and Informational, I recommend setting local logging to a relatively high priority level - i.e. warning and higher severity and increasing the defualt buffer size. Only use the more verbose levels when troubleshooting. Do not turn on "logging console" unless you are sitting at the console using it in real time. Otherwise is consumes unnecessary resources. Something like this: logging enablelogging timestamplogging buffer-size 100000logging asdm-buffer-size 512logging buffered warnings FYI here are the levels: Alert Messages, Severity 1Critical Messages, Severity 2Error Messages, Severity 3Warning Messages, Severity 4Notification Messages, Severity 5Informational Messages, Severity 6Debugging Messages, Severity 7

# %%
import string
def save_post_data_csv(posts,filename):
    
    csv = open(filename, "w",encoding='utf-8')
    columnTitleRow = "Heading,Content,Replies\n"
    csv.write(columnTitleRow)
    table = str.maketrans({key: None for key in string.punctuation})
    
    for post in posts:
        heading = post.heading.translate(table) 
        content = post.content.translate(table)
        
        if len(post.replies) > 1:
            replies = " RVCE ".join(post.replies)
            replies = str(replies).translate(table)
        else:
            replies = str(post.replies).translate(table)
            
        row = heading + "," + content + "," + replies+ "\n"
        csv.write(row)

# %%
save_post_data_csv(post_dat,"posts2.csv")

# %%
datap = pd.read_csv("Firewalling_data.csv")

print(len(datap))
datap.head(10)
# Out:
# 2460
#                                              Heading  \
# 0                   ASA 5508X FTDASDMFMC Limitations
# 1  Convert Asav Ova files to qcow2  and install i...
# 2  Cisco ASA DHCPPD and SLAAC with VPN Anyconnect...
# 3                       Cisco ASA use Sophos UTM IPS
# 4  Cisco ASA 5512 Blocking PPTP connection server...
# 5                           ASA High CPU Utilization
# 6  Cisco Firepower 2110 Threat Defense  Add anoth...
# 7    ASA with Websense  selective request forwarding
# 8                     Create packet on packet tracer
# 9  Need help understand ASA with firepower vs FTD...
#
#                                              Content  \
# 0  Hi I got this firewall on my hands running Cis...
# 1  Hi everybody I was tried to convert asavvmdk f...
# 2  Hi I finally got DHCPPD working with my ISP an...
# 3  HiI am trying to understand if the ASA can use...
# 4  Could any one please help me out with the solu...
# 5  I have trouble with ASA 5520 Dispatch unit con...
# 6  Hi All Cant believe I have to ask this but doe...
# 7  Hi AllI have been looking at URI filtering on ...
# 8  Good morning to everybody I have a problem wit...
# 9  Hi  I have to configure ASA with firepower ser...
#
#                                              Replies
# 0  Hello there I cannot answer your first questio...
# 1  Here is a guide on setting up the ASAv in GNS3...
# 2                                                NaN
# 3  Why wouldnt workIt ALL depends of the design y...
# 4  Please share the relevant config for this setu...
# 5  Having only one interface up on the ASA basica...
# 6                                                NaN
# 7  Hi again has anybody have any ideas on how to ...
# 8                                                NaN
# 9  Hello Nandan So you can do the update of the f...

# %%
datap.iloc[99]
# Out:
# Heading                                      Wipe out an ASA
# Content    hi alljust a quick one whats the best and prac...
# Replies    Write erase and reload will erase everything o...
# Name: 99, dtype: object

# %%
post_dat
# Out:
# [<__main__.post_data at 0x245c67bae10>,
#  <__main__.post_data at 0x245c8438a58>,
#  <__main__.post_data at 0x245c835ff60>,
#  <__main__.post_data at 0x245c55d8550>,
#  <__main__.post_data at 0x245c9649f60>,
#  <__main__.post_data at 0x245c851ab38>,
#  <__main__.post_data at 0x245c83faef0>,
#  <__main__.post_data at 0x245c708c470>,
#  <__main__.post_data at 0x245ca8f7198>,
#  <__main__.post_data at 0x245c6d34940>,
#  <__main__.post_data at 0x245c96cd6d8>,
#  <__main__.post_data at 0x245c85c2128>,
#  <__main__.post_data at 0x245c674fe80>,
#  <__main__.post_data at 0x245c6ba0470>,
#  <__main__.post_data at 0x245c692f048>,
#  <__main__.post_data at 0x245c81f4240>,
#  <__main__.post_data at 0x245c826acf8>,
#  <__main__.post_data at 0x245c6bf22b0>,
#  <__main__.post_data at 0x245c84f7eb8>,
#  <__main__.post_data at 0x245c6eb06a0>,
#  <__main__.post_data at 0x245c9702e48>,
#  <__main__.post_data at 0x245cac2c160>,
#  <__main__.post_data at 0x245ca798240>,
#  <__main__.post_data at 0x245c7014d30>,
#  <__main__.post_data at 0x245c8421898>,
#  <__main__.post_data at 0x245c6fbab70>,
#  <__main__.post_data at 0x245c6ee8710>,
#  <__main__.post_data at 0x245c55960b8>,
#  <__main__.post_data at 0x245c8443a58>,
#  <__main__.post_data at 0x245c85aa0b8>,
#  <__main__.post_data at 0x245c7000400>,
#  <__main__.post_data at 0x245c701a710>,
#  <__main__.post_data at 0x245c6caa908>,
#  <__main__.post_data at 0x245c85c22b0>,
#  <__main__.post_data at 0x245c5596ba8>,
#  <__main__.post_data at 0x245c6a8d6a0>,
#  <__main__.post_data at 0x245c6ba04a8>,
#  <__main__.post_data at 0x245c6f7dba8>,
#  <__main__.post_data at 0x245c55fbc88>,
#  <__main__.post_data at 0x245c82cf048>,
#  <__main__.post_data at 0x245c6bd3278>,
#  <__main__.post_data at 0x245c85d8588>,
#  <__main__.post_data at 0x245c6d5b588>,
#  <__main__.post_data at 0x245c6e37be0>,
#  <__main__.post_data at 0x245c55794e0>,
#  <__main__.post_data at 0x245c6c9b908>,
#  <__main__.post_data at 0x245c69aa668>,
#  <__main__.post_data at 0x245c85e59e8>,
#  <__main__.post_data at 0x245cac14d30>,
#  <__main__.post_data at 0x245c8286cc0>,
#  <__main__.post_data at 0x245c8446160>,
#  <__main__.post_data at 0x245c6714198>,
#  <__main__.post_data at 0x245c6f54668>,
#  <__main__.post_data at 0x245c96fa9b0>,
#  <__main__.post_data at 0x245c6a8d828>,
#  <__main__.post_data at 0x245c7077978>,
#  <__main__.post_data at 0x245c6ca7e80>,
#  <__main__.post_data at 0x245c6f46d30>,
#  <__main__.post_data at 0x245cab66be0>,
#  <__main__.post_data at 0x245c68fd1d0>,
#  <__main__.post_data at 0x245ca7ffbe0>,
#  <__main__.post_data at 0x245c6791d68>,
#  <__main__.post_data at 0x245c705f080>,
#  <__main__.post_data at 0x245c8453748>,
#  <__main__.post_data at 0x245c7021978>,
#  <__main__.post_data at 0x245c965afd0>,
#  <__main__.post_data at 0x245c6b24208>,
#  <__main__.post_data at 0x245c8450f60>,
#  <__main__.post_data at 0x245c9656da0>,
#  <__main__.post_data at 0x245c96a9d30>,
#  <__main__.post_data at 0x245c6f02588>,
#  <__main__.post_data at 0x245c842d198>,
#  <__main__.post_data at 0x245c81c74e0>,
#  <__main__.post_data at 0x245c85a9c88>,
#  <__main__.post_data at 0x245c6810ef0>,
#  <__main__.post_data at 0x245c6c74048>,
#  <__main__.post_data at 0x245c973b2e8>,
#  <__main__.post_data at 0x245c6be00f0>,
#  <__main__.post_data at 0x245ca84cc88>,
#  <__main__.post_data at 0x245c6a26f28>,
#  <__main__.post_data at 0x245c82ca1d0>,
#  <__main__.post_data at 0x245c55dea20>,
#  <__main__.post_data at 0x245c96a3dd8>,
#  <__main__.post_data at 0x245c6b7f160>,
#  <__main__.post_data at 0x245c8284278>,
#  <__main__.post_data at 0x245c6c7fac8>,
#  <__main__.post_data at 0x245c85f18d0>,
#  <__main__.post_data at 0x245ca9cc3c8>,
#  <__main__.post_data at 0x245c67e7668>,
#  <__main__.post_data at 0x245c68d4320>,
#  <__main__.post_data at 0x245c55ada20>,
#  <__main__.post_data at 0x245c68abc18>,
#  <__main__.post_data at 0x245c6b44a58>,
#  <__main__.post_data at 0x245ca76fc88>,
#  <__main__.post_data at 0x245c68d3438>,
#  <__main__.post_data at 0x245c6d34ef0>,
#  <__main__.post_data at 0x245c6cc4b38>,
#  <__main__.post_data at 0x245c6ca7d68>,
#  <__main__.post_data at 0x245c68ec0f0>,
#  <__main__.post_data at 0x245c6bace10>,
#  <__main__.post_data at 0x245c6b44748>,
#  <__main__.post_data at 0x245c707b080>,
#  <__main__.post_data at 0x245c8245d68>,
#  <__main__.post_data at 0x245c965ae48>,
#  <__main__.post_data at 0x245c6ee5668>,
#  <__main__.post_data at 0x245c6bbf2b0>,
#  <__main__.post_data at 0x245c7088c50>,
#  <__main__.post_data at 0x245c859b630>,
#  <__main__.post_data at 0x245c7000c50>,
#  <__main__.post_data at 0x245c81cf668>,
#  <__main__.post_data at 0x245c8621e80>,
#  <__main__.post_data at 0x245c96d1160>,
#  <__main__.post_data at 0x245c699c898>,
#  <__main__.post_data at 0x245c70922b0>,
#  <__main__.post_data at 0x245c705a550>,
#  <__main__.post_data at 0x245c6f9e8d0>,
#  <__main__.post_data at 0x245c8469ba8>,
#  <__main__.post_data at 0x245c6cc4c18>,
#  <__main__.post_data at 0x245c67ba978>,
#  <__main__.post_data at 0x245c82440b8>,
#  <__main__.post_data at 0x245c6ea5ef0>,
#  <__main__.post_data at 0x245c692ec50>,
#  <__main__.post_data at 0x245c9782b70>,
#  <__main__.post_data at 0x245c6904b38>,
#  <__main__.post_data at 0x245c708e828>,
#  <__main__.post_data at 0x245caa91588>,
#  <__main__.post_data at 0x245c708e048>,
#  <__main__.post_data at 0x245c55dc080>,
#  <__main__.post_data at 0x245c6ce3dd8>,
#  <__main__.post_data at 0x245c8210240>,
#  <__main__.post_data at 0x245c96127b8>,
#  <__main__.post_data at 0x245c67bc358>,
#  <__main__.post_data at 0x245c55de128>,
#  <__main__.post_data at 0x245c68f5be0>,
#  <__main__.post_data at 0x245c71450f0>,
#  <__main__.post_data at 0x245c6bc1470>,
#  <__main__.post_data at 0x245c8190d68>,
#  <__main__.post_data at 0x245c6b7fd68>,
#  <__main__.post_data at 0x245c6c9aa90>,
#  <__main__.post_data at 0x245c69d2438>,
#  <__main__.post_data at 0x245c55c8c88>,
#  <__main__.post_data at 0x245c829f438>,
#  <__main__.post_data at 0x245ca8dfa90>,
#  <__main__.post_data at 0x245c826ccc0>,
#  <__main__.post_data at 0x245c83965f8>,
#  <__main__.post_data at 0x245c6ec66d8>,
#  <__main__.post_data at 0x245c9649860>,
#  <__main__.post_data at 0x245c824fc50>,
#  <__main__.post_data at 0x245c81935f8>,
#  <__main__.post_data at 0x245c8530630>]

# %%
import pickle

def save_post_data(post_dat,filename,new_file = False,append = True):
    posts = []
    if not new_file and append :
        f = open(filename, "rb")
        posts = pickle.load(f)
        f.close()
    f = open(filename, "wb")
    posts.extend(post_dat)
    pickle.dump(posts,f,pickle.HIGHEST_PROTOCOL)
    f.close()
    return post_dat
    
def load_post_data(filename):
    f = open(filename, "rb")
    posts1 = pickle.load(f)
    f.close()
    return posts1

# %%
save_post_data(post_dat,"Firewalling_data.pkl",new_file = False,append = True)
post_dat1 = load_post_data("Firewalling_data.pkl")

# %%
len(post_dat1)
# Out:
# 2460

# %%
post_dat1[26].disp_info()
# Out:
# HEADING :	How Fast do ASA Failover Links Need to Be?
#
#
# POST :
#
# I'm curious if there are any recommendations about this. I'm setting up an active/standby pair of 5585s that have two 10g interfaces. The ports I'm planning on using for my failover (and stateful failover) are both 1g. Is this kosher or would the failover interfaces need to be closer to the performance of the production interfaces? It seems like the failover interfaces are only sharing information about config changes, and then the state table and that sort of thing. So maybe don't need to be as fast? Are there any recommendations on what the ratios between production interfaces and failover interfaces should be? Thanks, Ben
#
# REPLIES :
#
#
#
#
#
# Hello Ben, On an active/standby failover as far as I know, if firewall A dies, then firewall B takes over and the link between them does not play big role other than synchronizing the configuration from active to standby and checking to see what the status is between the two devices. I am running two 5525-x in active/standby and every time the failover had to kick in there was 1-3 pings lost and then you could not tell the difference in performance, since the link between them is not used for anything else. Note that I have the failover over a 1G port. Note, that I have never seen in Cisco literature any recommendation on failover link speeds for active/passive. I guess the story would be different though for active/active. Hope that makes sense. ------------------------------------------------------------------If this was helpful, please vote as helpful by clicking on the star icon below. -------------------------------------
#
#
# Right, but you're talking about basic failover. I'm talking about stateful failover where the firewalls pass real-time state table information back and forth so sessions don't have to re-establish in the event of a failover. (So there's no ping loss, for example.) In that case it's not that all traffic is shared, so it wouldn't have to be as fast as the production interfaces necessarily. But it's way more traffic than just a basic failover link.
#
#
# Hello Ben, I am talking about Stateful Failover in my case as well.I did a little bit of searching and under the Cisco ASA Series CLI Configuration Guide, 9.0 - Chapter: Information About Failover - Failover Interface Speed for Stateful Links it reads: "Use the following failover interface speed guidelines for the ASAs: Cisco ASA 5580/5585-X – Use only non-management 1 Gigabit ports for the stateful link because management ports have lower performance and cannot meet the performance requirement for Stateful Failover." So I guess 1 Gigabit should be fine, or you can use more than one 1 Gigabit ports, if you feel that it would make a difference. As I personally at least could not find any more details on that and from my setup, the 1 Gigabit port is fine, I would also try Cisco TAC for further advice. I hope that helps. ------------------------------------------------------------------If this was helpful, please vote as helpful by clicking on the star icon below. -------------------------------------
#
#
# I subscribe to AlexPi reply. To make sure we are right about this: just add failover interfaces to any SNMP monitoring interface and check traffic overview. If you want to go deep you can perform a manual failover and check traffic pattern on the failover interface during failover timeline. I wouldn't expect that much of a volume.

# %% [markdown]
# ## Premilinary Data Analysis

# %%
import pandas as pd
from IPython.display import display, HTML
wan_data = pd.read_csv("WAN_Routing_Switching_info.csv",parse_dates=['Date'])
lan_data = pd.read_csv("LAN_Switching_Routing_info.csv",parse_dates=['Date'])
ip_data = pd.read_csv("IP_telephony_info.csv",parse_dates=['Date'])
fire_data = pd.read_csv("Firewalling_info.csv",parse_dates=['Date'])

topic = ['WAN Routing and Switching','LAN Switching and Routing','IP telephony','Firewalling']
data = [wan_data,lan_data,ip_data,fire_data]

for i,df in enumerate(data):
    print(topic[i]+"  : "+str(len(df)))
    display(df.head())

#data.head(10)
# Out:
# WAN Routing and Switching  : 4800
#                                      Post       Date  Views  Replies  Upvotes  \
# 0  Cisco ISR4331K9 router errors out of b 2018-05-02    146        4       10
# 1  bcp38 vs ipv4 verify unicast source re 2018-05-09     92        2        0
# 2                  Routing  traffic issue 2018-05-08    234       10        0
# 3                ASR 1006  SASR1R2AISK9MS 2018-05-10    102        0        0
# 4                   NBAR2 and MS OneDrive 2018-05-10     83        0        0
#
#                                                 Link  Resolved
# 0  https://supportforums.cisco.com//t5/wan-routin...         0
# 1  https://supportforums.cisco.com//t5/wan-routin...         0
# 2  https://supportforums.cisco.com//t5/wan-routin...         0
# 3  https://supportforums.cisco.com//t5/wan-routin...         0
# 4  https://supportforums.cisco.com//t5/wan-routin...         0
# LAN Switching and Routing  : 10500
#                                     Post       Date  Views  Replies  Upvotes  \
# 0  IOS Upgrade on cisco WSC6509E switche 2018-05-23     83        1        0
# 1  C68008P10G Interface Module Installat 2018-05-23    141        6        0
# 2            Cisco ACI mode vs NXOS Mode 2018-05-22    217        3        0
# 3             Visio stencil CISCO 892FSP 2016-11-14    586        4        0
# 4            Problem with a simple route 2018-05-22    129        5       10
#
#                                                 Link  Resolved
# 0  https://supportforums.cisco.com//t5/lan-switch...         0
# 1  https://supportforums.cisco.com//t5/lan-switch...         1
# 2  https://supportforums.cisco.com//t5/lan-switch...         1
# 3  https://supportforums.cisco.com//t5/lan-switch...         0
# 4  https://supportforums.cisco.com//t5/lan-switch...         0
# IP telephony  : 6749
#                                   Post       Date  Views  Replies  Upvotes  \
# 0         CME 121 8851 KEM not working 2018-04-05    167        7        0
# 1      SIP phones DN and Pool concepts 2018-05-23     79        2       10
# 2                CP 8851  Set password 2018-04-26    289        9       20
# 3   DTMF Issues with SIP Phones on CME 2018-05-22     60        1        0
# 4  Callforward all to SIP CME 15 Issue 2018-05-22     73        3        0
#
#                                                 Link  Resolved
# 0  https://supportforums.cisco.com//t5/ip-telepho...         0
# 1  https://supportforums.cisco.com//t5/ip-telepho...         0
# 2  https://supportforums.cisco.com//t5/ip-telepho...         1
# 3  https://supportforums.cisco.com//t5/ip-telepho...         0
# 4  https://supportforums.cisco.com//t5/ip-telepho...         0
# Firewalling  : 3750
#                                       Post       Date  Views  Replies  \
# 0         ASA 5508X FTDASDMFMC Limitations 2018-05-16    181        1
# 1   Convert Asav Ova files to qcow2 and in 2018-05-15     92        2
# 2   Cisco ASA DHCPPD and SLAAC with VPN An 2018-05-15    155        0
# 3             Cisco ASA use Sophos UTM IPS 2018-05-14    185        4
# 4  Cisco ASA 5512 Blocking PPTP connection 2018-05-11    193       10
#
#    Upvotes                                               Link  Resolved
# 0        5  https://supportforums.cisco.com//t5/firewallin...         1
# 1        0  https://supportforums.cisco.com//t5/firewallin...         0
# 2        0  https://supportforums.cisco.com//t5/firewallin...         0
# 3        0  https://supportforums.cisco.com//t5/firewallin...         0
# 4        0  https://supportforums.cisco.com//t5/firewallin...         0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filtered_data = [df[(df['Date'] > '2017-01-01') & (df['Date'] < '2018-05-01')] for df in data]

# %%
date_hits = pd.DataFrame()
for i, df in enumerate(filtered_data):
    date_hits[topic[i]] = df['Date'].value_counts().sort_index()

# %%
date_hits.head()
# Out:
#             WAN Routing and Switching  LAN Switching and Routing  \
# 2017-01-02                          6                          8
# 2017-01-03                         10                         15
# 2017-01-04                          8                         23
# 2017-01-05                          5                         19
# 2017-01-06                         12                          9
#
#             IP telephony  Firewalling
# 2017-01-02          14.0          4.0
# 2017-01-03           8.0          6.0
# 2017-01-04          16.0         15.0
# 2017-01-05          11.0          5.0
# 2017-01-06           8.0          7.0

# %% [markdown]
# ##### Number of posts Vs. Day
# this plot gives an idea of daily traffic on the domain

# %%
ax = date_hits.plot(kind = 'line',figsize = (9,6),grid=True )
ax.set_ylabel('number of posts')

# %% [markdown]
# this density plot shows that mostly the number of posts made on a day is between 10 to 30

# %%
date_hits.plot(kind = 'density',figsize = (9,6),grid = True)

# %% [markdown]
# #### Monthly Analysis
#
# As from the bar chart shown below it can be seen that the number of posts in each month has low standard deviation and remains fairly constant maybe we can get a better insight of data by analysing the individual post text.

# %%
monthly_hits = pd.DataFrame()
for i, df in enumerate(filtered_data):
    monthly_hits[topic[i]] = df['Date'].groupby(df.Date.dt.to_period("M")).agg('count')

monthly_hits.head()
# Out:
#          WAN Routing and Switching  LAN Switching and Routing  IP telephony  \
# Date
# 2017-01                        248                        485           361
# 2017-02                        218                        541           419
# 2017-03                        211                        614           383
# 2017-04                        211                        489           332
# 2017-05                        246                        549           361
#
#          Firewalling
# Date
# 2017-01          193
# 2017-02          183
# 2017-03          230
# 2017-04          193
# 2017-05          212

# %%
ax = monthly_hits.plot(kind = 'line',grid = True,figsize = (9,6))
ax.set_ylabel('number of posts')

# %% [markdown]
# Most months have posts ranging between 450 to 550.

# %%
monthly_hits.plot(kind = 'density',figsize = (9,6),grid = True)

# %% [markdown]
# #### Community Scoring
# The activity of any forum is not only based on the number of posts posted but also based on how actively the community participates to solve ones problem.

# %%
replied_posts =  [df[((df['Replies']) > 0 ) & ( df['Date'] > '2017-01-01') & (df['Date'] < '2018-05-01') ]  for df in data]

# %%
reply_percentage = [len(rp)*100//len(fd) for rp,fd  in list(zip(replied_posts,filtered_data))]
for percent in reply_percentage:
    print("\nPercentage of posts which have got atleast one reply : {} %\n".format(percent))
# Out:
# Percentage of posts which have got atleast one reply : 86 %
#
#
# Percentage of posts which have got atleast one reply : 86 %
#
#
# Percentage of posts which have got atleast one reply : 87 %
#
#
# Percentage of posts which have got atleast one reply : 84 %

# %%
upvoted_posts = [df[((df['Upvotes']) > 0) &(df['Date'] > '2017-01-01') & (df['Date'] < '2018-05-01')] for df in data]

# %%
upvote_percentage = [len(up)*100//len(fd) for up,fd  in list(zip(upvoted_posts,filtered_data))]
for percent in upvote_percentage:
    print("\nPercentage of posts which have got atleast one reply and marked helpful: {} %\n".format(percent))
# Out:
# Percentage of posts which have got atleast one reply and marked helpful: 21 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 20 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 23 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 20 %

# %%
resolved_posts = [df[((df['Resolved']) > 0) &(df['Date'] > '2017-01-01') & (df['Date'] < '2018-05-01')] for df in data]
resolved_percentage = [len(up)*100//len(fd) for up,fd  in list(zip(resolved_posts,filtered_data))]
for percent in resolved_percentage:
    print("\nPercentage of posts which have got atleast one reply and marked helpful: {} %\n".format(percent))
# Out:
# Percentage of posts which have got atleast one reply and marked helpful: 27 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 27 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 25 %
#
#
# Percentage of posts which have got atleast one reply and marked helpful: 29 %

# %%
raw_data = {
    'topic' : ['WAN','LAN','IP Telephony','Firewalling'],
    'upvote':upvote_percentage,
    'reply' : reply_percentage,
    'resolved' : resolved_percentage
}
activity = pd.DataFrame(raw_data, columns = ['topic', 'upvote', 'reply', 'resolved'])

# %%
activity
# Out:
#           topic  upvote  reply  resolved
# 0           WAN      21     86        27
# 1           LAN      20     86        27
# 2  IP Telephony      23     87        25
# 3   Firewalling      20     84        29

# %%
ax = activity.plot(kind = 'bar',grid = True,x = 'topic',figsize = (9,6),rot = 1,colormap = 'rainbow')
ax.set_ylabel('percentage')

# %%
views = []
for i, df in enumerate(filtered_data):
    views.append(df['Views'].sum())

# %%
import numpy as np
x = np.arange(4) +1
plt.xlabel('topics')
plt.ylabel('views')
plt.get_cmap('jet')
plt.bar(x, height= views)
plt.xticks(x+0.4, ['WAN','LAN','IP Telephony','Firewalling'])

# %%
monthly_resolved = pd.DataFrame()
for i, df in enumerate(resolved_posts):
    monthly_resolved[topic[i]] = df['Date'].groupby(df.Date.dt.to_period("M")).agg('count')
# Out:
#          WAN Routing and Switching  LAN Switching and Routing  IP telephony  \
# Date
# 2017-01                         65                        124            75
# 2017-02                         67                        160            93
# 2017-03                         39                        137            77
# 2017-04                         56                        126            65
# 2017-05                         62                        134            83
# 2017-06                         54                         96            73
# 2017-07                         44                        122            68
# 2017-08                         56                        119            66
# 2017-09                         65                        144            68
# 2017-10                         94                        134            78
# 2017-11                         54                        162            59
# 2017-12                         54                        123            74
# 2018-01                         64                        197           110
# 2018-02                         75                        200           113
# 2018-03                         76                        154            88
# 2018-04                         66                        159            84
#
#          Firewalling
# Date
# 2017-01           61
# 2017-02           69
# 2017-03           63
# 2017-04           41
# 2017-05           58
# 2017-06           48
# 2017-07           44
# 2017-08           50
# 2017-09           57
# 2017-10           46
# 2017-11           70
# 2017-12           43
# 2018-01           50
# 2018-02           62
# 2018-03           58
# 2018-04           46

# %%
ax = monthly_resolved.divide(monthly_hits).plot(kind = 'line',grid= True,figsize = (9,6))
ax.set_ylabel('fraction resolved')

# %% [markdown]
# ### Post Text based analysis

# %%
import nltk
from nltk.corpus import stopwords
import string
from collections import Counter


stopword_file = open("terrier-stop.txt","r")
t_stop = stopword_file.read().splitlines()

# %%
def comment_cleaner(comment):
    
    words = nltk.word_tokenize(comment)
    words = [word.lower() for word in words if word.isalpha()]
    table = str.maketrans('', '', string.punctuation)
    words = [word.translate(table) for word in words]
    words = [word for word in words if word.isalpha()]
    
    word_tags = nltk.pos_tag(words)
    
    #words = [word for word,tag in word_tags if tag in ('NN','JJ','NNP','NNS','NNPS')]
    #words.extend([word[-1] for word,tag in word_tags if tag in ('NNS','NNPS')])
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if not word in stop_words]
    words = [word for word in words if not word in t_stop]
    # stemming of words
    #lemma = nltk.stem.wordnet.WordNetLemmatizer()
    #words = [lemma.lemmatize(word) for word in words]
        
    #porter = PorterStemmer()
    #words = [porter.stem(word) for word in words]
    cleaned_comment = ' '.join(words)
    
    return cleaned_comment

# %%
post_list = [filtered_data[i]['Post'].tolist() for i in range(len(filtered_data))]

# %%
all_posts = []
all_words = []
for i in range(len(filtered_data)):
    #all_posts = " ".join(str(post) for post in post_list)
    cleaned_posts = [comment_cleaner(str(post)) for post in post_list[i]]
    all_posts.append(" ".join(cleaned_posts))
    all_words.append(all_posts[i].split())

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords_w = set(STOPWORDS)

for i in range(len(filtered_data)):
    print(topic[i]+"\n\n")
    wordcloud = WordCloud(
                              background_color='black',
                              stopwords=stopwords_w,
                              max_words=300,
                              max_font_size=40, 
                              random_state=42
                             ).generate(all_posts[i])

    plt.figure(figsize=(9,6))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
# Out:
# WAN Routing and Switching
# LAN Switching and Routing
# IP telephony
# Firewalling

# %%
len(post_dat)
# Out:
# 150

# %%
post_dat = post_dat[:150]
